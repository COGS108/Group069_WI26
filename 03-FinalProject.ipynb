# %% [markdown]
# # Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
# Scoring: Out of 18 points in total.  15 points in the report.  3 points in the video summary of your report for a non-technical audience.
#
# For the report:
# - Each Developing  => -0.5 pts
# - Each Unsatisfactory/Missing => -1 pts
#   - until the score is 0
#
# For the video:
# - Developing  => -1.5 pts
# - Unsatisfactory/Missing => -3 pts
#
# |                                                                                    | Unsatisfactory                                                                                                                                                                                                                                                                                      | Developing                                                                                                                                                                                                                                                                                                                          | Proficient                                                                                                                                                                                                                                                    | Exellent                                                                                                                                                                                                                                                                                                                                                          |
# | ---------------------------------------------------------------------------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | Title & abstract                                                                   | Title or abstract is confusing or fails to offer important details about the question, variables, context, or methods of the project.                                                                                                                                                               | Title or abstract lacks relevance or fails to offer appropriate details about the question, variables, context, or methods of the project.                                                                                                                                                                                          | Title and abstract are relevant, offering sufficient details about the research project.                                                                                                                                                                      | Title and abstract are informative, succinct, and clear. It offers specific details about the question, variables, context, and proposed methods of the study.                                                                                                                                                                                                    |
# | Background                                                                         | Did not have at least 3 reliable and relevant sources. Or relevant sources were not used in relevant ways                                                                                                                                                                                           | A key component was not connected to the research literature. Selected literature was from unreliable sources. Literary supports were vague or ambiguous.                                                                                                                                                                           | Key research components were connected to relevant, reliable literature.                                                                                                                                                                                      | Narrative integrates critical and logical details from the peer-reviewed or other professional research literature. Each key research component is grounded to the literature. Attention is given to different perspectives, threats to validity, and opinion vs. evidence.                                                                                       |
# | Research question & hypothesis                                                     | Research issue remains unclear. The research purpose, questions, hypotheses, definitions or variables and controls are still largely undefined, or when they are are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Research issue is identified, but statement is too broad or fails to establish the importance of the problem. The research purpose, questions, hypotheses, definitions or variables and controls are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Identifies a relevant research issue. Research questions are succinctly stated, connected to the research issue, and supported by the literature. Variables and controls have been identified and described. Connections are established with the literature. | Presents a significant research problem related to the chemical sciences. Articulates clear, reasonable research questions given the purpose, design, and methods of the project. All variables and controls have been appropriately defined. Proposals are clearly supported from the research and theoretical literature. All elements are mutually supportive. |
# | Data description                                                                   | Did not have references to relevant data sources for this problem. Did not describe the data obtained at those sources                                                                                                                                                                              | A key data source was not referenced or described in satisfactory level of detail                                                                                                                                                                                                                                                   | All relevant data sources were referenced and described in terms of their key variables and size                                                                                                                                                              | Multiple data sources for each aspect of the project, All data sources are fully described and referenced. The details of the descriptions also make it clear how they support the needs ot the project.                                                                                                                                                          |
# | Data wrangling                                                                     | Data obviously not tidy and not clean. Or even if they are clean/tidy, there was no demonstration of that fact                                                                                                                                                                                      | Data has some minor problems with tidiness or cleanliness. Potentially these are not problems but it wasn't fully demonstrated to be the case in the code                                                                                                                                                                           | Data are made tidy and clean, or are clearly demonstrated to be so from download                                                                                                                                                                              | Data wrangling is complete, but also particularly thoroughly done for a very tough case. Often free text parsing is a bear like this, and doing it well can mean a million edge cases.                                                                                                                                                                            |
# | Data visualizations                                                                | Many plots don't capture useful information, or their display of information is difficult to understand.. Legends, labels, axes, titles, captions, etc of many plots may be poor or missing. Figures are not referenced in the main text.                                                           | Most plots make sense and capture useful information. Legends, labels, axes, titles, captions, etc are mostly legible and adequately describe the content of the figure. Most figures are referenced or explained inside the main text and not just left hanging.                                                                   | Plots make sense and capture useful information. Legends, labels, axes, titles, captions, etc are clearly legible and adequately describe the content of the figure. Figures are referenced or explained inside the main text and not just left hanging.      | Plots are beautiful and information dense. Legends, labels, axes, titles, captions, etc clearly describe the content of the figure. Figures are well integrated with the text.                                                                                                                                                                                    |
# | Data analysis and results                                                          | Lacks any metrics or at least metrics that are relevant to the problem                                                                                                                                                                                                                              | Some metrics selected are not appropriate for the problem or the metrics selected are not described sufficiently                                                                                                                                                                                                                    | All metrics described are appropriate and and described sufficiently                                                                                                                                                                                          | The metrics are described clearly and succinctly. Their appropriateness for addressing the research problem is clearly described.                                                                                                                                                                                                                                 |
# | Ethics                                                                             | Only tries a baseline model, never advances to proper model/hyper-parameter selection                                                                                                                                                                                                               | Only investigates one minimal aspect of their problem, e.g. just did a single hyperparameter selection on a single model                                                                                                                                                                                                            | Does a good model/hyper-parameter selection. Only attempts minimal secondary analysis                                                                                                                                                                         | Does a good model/hyper-parameter selection. Performs multiple secondary analysis such as learning curves, heat maps looking at where in the parameter space things are good/bad, uses statistical testing                                                                                                                                                        |
# | Conclusion and discussion                                                          | Doesn't have a narrative/conclusions of what the report accomplished. Or very minimal conclusions, like "X was best" without anything else                                                                                                                                                          | Has narrative/conclusions, but it feels perfunctory and lacks context. Especially if the limitations and ethics sections are largely junk or missing                                                                                                                                                                                | Properly recapitulates the results and provides context for them. Has a sense of the limitatins and ethical issues.                                                                                                                                           | Clearly recapitulates the results and provides context, including the literature/background Has a sense of what to do next, and has good explorations of the limitations and ethics.                                                                                                                                                                              |
# | Documentation and written communication                                            | Code documentation is non-existent or perfunctory. Writing has usage errors, poor fluency, and poor rhetoric. If doc/writing are both like this you get unsatisfacory. If one is unsatisfactory and the other is developing you still get unsatisfactory overall.                                   | Code documentation is only partially there. Writing has some usage errors, some poor fluency, or some poor rhetoric. If doc/writing are both like this you get developing. If one is developing and the other is satisfactory you still get developing.                                                                             | Code is documented throughout. Writing has good fluency, good rhetoric, and at most a few minor errors.                                                                                                                                                       | Code documentation is highly informative with docstrings. Writing is high quality. If both doc/writing are like this you get excellent. If one is satisfactory and the other excellent you still get satisfactory.                                                                                                                                                |
# | Video (developing -1.5 points, unsatisfactory -3 points)                           | Video well outside the 3-5min time range. Does not communicate major results at a non-technical level. Has major technical issues such as no sound or not available at link. Unsatisfactory if 2/3 of these are true                                                                                | Video just outside the 3-5min time range. Does not communicate well on some points (either wrong tech level or just confusing). Has technical issues such as poor speech quality on video. Developing if 2/3 of these are true                                                                                                      | Video has good quality and is in within 3-5 min range. Communicates the major results at an accessible level for non-technical people.                                                                                                                        | Video has high production quality and is in within 3-5 min range. Communicates the major results clearly and gives a sense of the methods at an accessible level for non-technical people. Has a wow factor (e.g. funny or original approach)                                                                                                                     |
# | Quality modifier (can result in extra credit beyond 18 points for this assignment) | Almost everything was just barely proficient. Lots of minimal effort work. Do not double punish; if they already lost points on the rubric do not invoke this: -0.5 points                                                                                                                        |                                                                                                                                                                                                                                                                                                                                     |                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                       More than 5 excellents on this rubric: +0.5 points                                                                                   |

# %% [markdown]
# # COGS 108 - Final Project (change this to your project's title)
#
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public, including the names of the authors.
#
# * [  ] YES - make available
# * [  ] NO - keep private
#
# ## Link to video
# https://link.to.your.publicly.viewable.video
#
# ## Abstract
#
#   Homicide remains a critical public health concern in the United States, yet state-level analyses that account for demongraphic convarities are underrepresented in most research. Massachusetts is an great case to study since it provides a valuable context for examining how victim demographics shape homicide mortality over time due to its diverse urban and rural populations.
#
#   This study investigates where a statistically significant relationship exists between the age of homicide victims and homicide death patterns in Massachusetts from 1999 to 2024, while controling for gender and marital status. Mortality data were obtained from the CDC WONDER National Vital Satistics System, using ICD-10-cause-of-death codes for homicide and filtered by age, group, sex, and marital status.
#
#   Data was cleaned, organized, and visualized to examine any trends over the 25-year period. Statisical analyses were conducted to assess the independent association between victim age and homicide mortality after adjusting for the control variables.
#
#   Findings revealed that _______. Overall this study highlights the importance of age consideration when developing violence prevention strategies in Massachusetts and contributes to the growing research on homicide victimization demographics.

# %% [markdown]
# ## Authors
# - Lucy Krych : Analysis, Project Administration, Methodology, Conceptualization
# - Minsui Tang : Analysis, Project Administration, Writing - original draft, Methodology, Software
# - Joey Ye : Writing - original draft, Writing - review and editing, Conceptualization
# - Affaan Hassan : Analysis, Data Curation, Writing - original draft, Software, Visualization
# - Patricio Ordonez-Acosta : Writing - original draft, Background research, Software, Writing - original draft

# %% [markdown]
# ## Research Question

# %% [markdown]
# While controlling for gender and marital status, is there a relationship between homicide death patterns in Massachusetts from 1999 - 2024 and the age of its victims?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Early criminological work and national surveillance data suggest that homicide is not evenly distributed throughout the year, with many studies reporting higher rates during warmer months. A data collection from the Bureau of Justice Statistics<a name="cite_note-1"></a>[<sup>1</sup>](#cite_ref-1) found that violent crime tends to increase in the summer, often attributed to greater outdoor activity, increased social interaction, and higher ambient temperatures, which possibly elevates aggression and opportunity for conflict, although the difference is quite small (about 4%).
#
# A closely related project “Crime Seasonality Analysis”<a name="cite_note-2"></a>[<sup>2</sup>](#cite_ref-2) from GitHub investigates whether crime exhibits predictable seasonal structure by treating crime counts as a time series. The data was sourced from NYC Open Data<a name="cite_note-3"></a>[<sup>3</sup>](#cite_ref-3) and the City of Chicago data portal<a name="cite_note-4"></a>[<sup>4</sup>](#cite_ref-4). Methodologically, the project’s pipeline is similar to our project question. The author grouped crime incidents by month and created graphs to see if some months consistently had higher crime than others. Similarly to the data collection from BJS, their result showed that crime is not evenly spread across the year. They also noted that some types of crime show clearer seasonal patterns than others. An important takeaway we noticed was that patterns from New York City and Chicago are not universal — combined data from both cities yielded more ambiguous results than data analyzed separately, which is also a common statistical phenomenon known as Simpson’s Paradox<a name="cite_note-5"></a>[<sup>5</sup>](#cite_ref-5). From this, we will take into consideration that crime seasonality is fluid and depends on location/time period, rather than following one fixed national pattern, and that any potential pattern we find is likely not permanent. Thus, we will also test whether homicide patterns change over time.
#
# ## References
#
# Kposowa, A. J., Singh, G. K., & Breault, K. D. (1994). The effects of marital status and
# social isolation on adult male homicides in the United States: Evidence from the National
# Longitudinal Mortality Study. *Journal of Quantitative Criminology, 10*(3), 277–289.
# https://doi.org/10.1007/BF02221213
#
# Kposowa, A. J. (1996). The effects of marital status on adult female homicides in the
# United States. *Journal of Quantitative Criminology, 12*(2), 113–134.
# https://doi.org/10.1007/BF02221308
#
# Massachusetts Department of Public Health. (2015). *Violent deaths in Massachusetts:
# Surveillance update 2015.* Commonwealth of Massachusetts.
# https://www.mass.gov/doc/violent-deaths-in-massachusetts-surveillance-update-2015/download
#
# Prothrow-Stith, D. (1987). *Violence in Massachusetts: The epidemiology of homicide in
# Massachusetts, 1977–1983.* Office of Justice Programs.
# https://www.ojp.gov/ncjrs/virtual-library/abstracts/violence-massachusetts-epidemiology-homicide-massachusetts-1977
#
# Sabri, B., Greene, M. C., Dang, Q., Wiener, J., & Stack, C. (2021). Characteristics,
# incidence, and trends of intimate partner homicides in Massachusetts: Patterns by
# birthplace, race, and ethnicity. *Journal of Family Trauma, Child Custody and Child
# Development, 18*(4), 353–371.
# https://doi.org/10.1080/26904586.2021.1882921
#
# Strassle, P. D., Stein, E., Bhatt, D. L., & Mensah, G. A. (2025). Homicide rates across
# county, race, ethnicity, age, and sex in the US: A Global Burden of Disease study.
# *JAMA Network Open, 8*(2), e2460022.
# https://doi.org/10.1001/jamanetworkopen.2024.60022
#
# U.S. Centers for Disease Control and Prevention. (n.d.). *CDC WONDER: Underlying cause
# of death, 1999–2020.* U.S. Department of Health and Human Services.
# https://wonder.cdc.gov/deaths-by-underlying-cause.html

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# Null: There is no difference in the distribution of age or marital status between homicide and non-homicide deaths in this dataset. Any observed differences are due to random variation within the sample.
#
# Alternative: Homicide rates vary and change based on age group and marital status of a person.
#
# Our Hypothesis: We expect that homicide deaths in this dataset will be more concentrated among younger individuals and those classified as single, while non-homicide deaths will be more common among older individuals and those who are married, divorced, or widowed. However, we anticipate that differences in marital status are largely explained by age distributions, rather than an independent relationship.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# Our primary dataset records information on individual births and deaths, with each row representing a single person. Key variables include **date of birth**, **date of death**, **marital status**, and **manner of death**.
#
# For effective analysis, the dataset should:
#
# - Span multiple years, allowing trends over time to be examined.
# - Include columns for month and year of death, enabling sorting by month and tracking patterns across years.
# - Be geographically diverse, avoiding concentration in a single area.
# - Be collected in a random manner to reduce sampling bias.
# - Have a large sample size, ensuring results are statistically robust and not overly influenced by chance.
#
# A potential issue with non-random sampling could occur if data were only gathered from a specific, high-end funeral home; this would bias the dataset toward wealthier individuals.

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2

# %%
# Setup code -- Run only once after cloning!!! 
#
# this code downloads the data from its source to the `data/00-raw/` directory
# if the data hasn't updated you don't need to do this again!

# if you don't already have these packages (you should!) uncomment this line
# %pip install requests tqdm

import sys
sys.path.append('./modules') # this tells python where to look for modules to import

import get_data # this is where we get the function we need to download data

# replace the urls and filenames in this list with your actual datafiles
# yes you can use Google drive share links or whatever
# format is a list of dictionaries; 
# each dict has keys of 
#   'url' where the resource is located
#   'filename' for the local filename where it will be stored

# %% [markdown]
# ### Dataset: Individual-Level Mortality Records with Birthday Proximity (The Pudding “Birthday Effect” Dataset)
#
# https://github.com/the-pudding/data/tree/master/birthday-effect.
#
# This dataset contains approximately 1.96 million individual mortality records across 7 columns, with each row representing a single person’s death. Key variables include date of birth, date of death, marital status, age, sex, place of residence, and manner of death.
#
# Our focuses for analysis are:
#
# - **Manner of death** – to examine homicide rates relative to other causes of death.
# - **Marital status and age** – to compare homicide rates across different demographic groups.
# - **Date of death** – to identify seasonal patterns and trends over time.
#
# This dataset closely matches our ideal dataset, providing all the desired variables plus additional demographic information and a large sample size. However, a few considerations remain:
#
# - Some entries may have missing or incomplete data for certain variables.
# - Although the dataset is extensive, there may be sampling biases related to geographic or demographic coverage.
#
#
# #### Potential Concerns and Limitations
#
# - **Geographic scope:** The dataset only includes births and deaths in Massachusetts, so any generalizations beyond this state should be made cautiously.
# - **Unknown sampling methods:** The methods used to collect the data are not documented. This raises the possibility of sampling bias, similar to the issue noted earlier, where certain demographics may be over- or under-represented.
# - **Missing or incomplete data:** Some demographic variables, such as marital status, may have missing values that are not missing at random, and certain age groups or manners of death may be disproportionately affected.
# - **Data formatting:** Birth and death dates are stored as strings and will need to be converted to datetime format for accurate analysis.
#
#
# #### Important Variables and Metrics
#
# 1. age_floor (integer, years): The age at death, rounded down to the nearest whole year. Units are years. Typical human lifespan ranges from 0 to roughly 110–120 years. Values outside this range may indicate data errors.
#
# 2. sex (categorical): Biological sex category. (Male and female)
# 3. marital (categorical): Marital status at time of death.
#
# * m: married
# * s: single
# * d: divorced
# * w: widowed
#
# 5. manner (categorical): Manner of death
# * n = Natural
# * a = Accident
# * s = Suicide
# * h = Homicide
# * c = Could not determine
# * p = Pending investigation
# * t = Therapeutic complication (medical/surgical complication

# %% [markdown]
# ### Loading Raw Data

# %%
import pandas as pd
import numpy as np
import os

os.makedirs("data/00-raw", exist_ok=True)
os.makedirs("data/01-interim", exist_ok=True)
os.makedirs("data/02-processed", exist_ok=True)

url = "https://raw.githubusercontent.com/the-pudding/data/refs/heads/master/birthday-effect/birthdays.csv"
local_path = "data/00-raw/birthdays.csv"

# if os.path.exists(local_path):
#     df = pd.read_csv(local_path)
# else:
#     df = pd.read_csv(url)
#     df.to_csv(local_path, index = False)

df = pd.read_csv(local_path)
df
# Out:
#               birth       death  age_floor  days_from_birthday  sex marital  \
# 0        1988-11-22  1990-09-26          1                 -57    f       s
# 1        1988-02-09  1990-01-07          1                 -33    f       s
# 2        1988-04-01  1990-02-13          1                 -47    m       s
# 3        1988-04-11  1990-02-24          1                 -46    f       s
# 4        1988-08-14  1990-02-27          1                -168    f       s
# ...             ...         ...        ...                 ...  ...     ...
# 1955583  1903-01-15  2016-10-02        113                -105    f       w
# 1955584  1910-02-18  2023-09-19        113                -152    f       s
# 1955585  1911-02-28  2024-11-16        113                -104    f       w
# 1955586  1885-11-19  1999-12-02        114                  13  NaN       w
# 1955587  1908-06-19  2023-05-25        114                 -25    f       w
#
#         manner
# 0            n
# 1            n
# ...

# %% [markdown]
# ### Tidying Dataset
#
# Not too much to do because the dataset is already tidy; each row represents only one individual record, each column represents one single variable, and each cell contains one value. No further tidying necesary.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1955588 entries, 0 to 1955587
# Data columns (total 7 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   birth               object
#  1   death               object
#  2   age_floor           int64
#  3   days_from_birthday  int64
#  4   sex                 object
#  5   marital             object
#  6   manner              object
# dtypes: int64(2), object(5)
# memory usage: 104.4+ MB

# %% [markdown]
# ### Dataset Size

# %%
print("Shape:", df.shape)
print("Total rows:", df.shape[0])
print("Total columns:", df.shape[1])
# Out:
# Shape: (1955588, 7)
# Total rows: 1955588
# Total columns: 7

# %% [markdown]
# ### Keep only important columns

# %% [markdown]
# We are only looking at age, marital status, sex, and manner of death in our study so we will drop extra columns to declutter

# %%
df = df[["age_floor", "sex", "marital", "manner"]]
df
# Out:
#          age_floor  sex marital manner
# 0                1    f       s      n
# 1                1    f       s      n
# 2                1    m       s      n
# 3                1    f       s      n
# 4                1    f       s      n
# ...            ...  ...     ...    ...
# 1955583        113    f       w      n
# 1955584        113    f       s      n
# 1955585        113    f       w      n
# 1955586        114  NaN       w      n
# 1955587        114    f       w      n
#
# [1955588 rows x 4 columns]

# %% [markdown]
# ### Check for and clean Missing Data
#
#     The dataset contains minimal missing data in most core variables (birth, death, age_floor). Marital status and manner contain <1% missing values. However, sex shows a 41% missing rate.

# %%
missing_counts = df.isna().sum()
missing_percent = df.isna().mean() * 100

missing_summary = pd.DataFrame({
    "missing_count": missing_counts,
    "missing_percent": missing_percent
}).sort_values("missing_percent", ascending=False)

missing_summary
# Out:
#            missing_count  missing_percent
# sex               822646        42.066427
# manner             10148         0.518923
# marital             1627         0.083197
# age_floor              0         0.000000

# %% [markdown]
# We don't want to drop 41% of our data, and it is likely that the missingness is not completely random (Women might choose to decline to state sex more often). Instead, we decided to fill missing sex values with d (declined to state), so we can see if declining to state sex has an effect. Other than that, missingness in the marital variable appears to be extremely low across all manner categories. The variation between groups is minimal, and several categories show no missing values at all. Because the missing rates are both very small and relatively similar across groups, there is no strong evidence that missingness is systematically associated with manner of death. This suggests that missing marital data is likely missing at random rather than structurally biased. Missing data from these categories will be dropped.

# %%
df_clean = df.fillna({"sex":"d"}, inplace = False)
df_clean = df_clean.dropna()

missing_counts = df_clean.isna().sum()
missing_percent = df_clean.isna().mean() * 100

missing_summary = pd.DataFrame({
    "missing_count": missing_counts,
    "missing_percent": missing_percent
}).sort_values("missing_percent", ascending=False)

missing_summary
# Out:
#            missing_count  missing_percent
# age_floor              0              0.0
# sex                    0              0.0
# marital                0              0.0
# manner                 0              0.0

# %% [markdown]
# ### Outliers and Suspicious Entries

# %%
flag_age = (df_clean["age_floor"] < 0) | (df_clean["age_floor"] > 90)
flag_sex = (((df_clean["sex"] == "m") | (df_clean["sex"] == "f")) | (df_clean["sex"] == "d")).apply(lambda x: not x)

marital = df_clean["marital"]
flag_marital = (((marital == "m") | (marital == "s")) | ((marital == "d") | (marital == "w"))).apply(lambda x: not x)

manner = df_clean["manner"]
def manner_checker(val):
    for letter in ["nashcpt"]:
        # n, a, s, h, c, p, t are the indicators for manner of death (n = natural, a = accident, etc)
        if val == letter:
            return False
flag_manner = manner.apply(manner_checker)

print(f"Weird Age values: {flag_age.sum()}")
print(f"Weird Sex values: {flag_sex.sum()}")
print(f"Weird Marital values: {flag_marital.sum()}")
print(f"Weird Manner values: {flag_manner.sum()}")
# Out:
# Weird Age values: 280207
# Weird Sex values: 6
# Weird Marital values: 4661
# Weird Manner values: 0

# %% [markdown]
# Ages are all between 0 and 90, all manners of death are described, and there are only 4 rows that have a value of sex other than m, f, or d
# However, marital has a little under 2000 entries that are something not described by our dataset

# %%
df_clean["marital"].value_counts()
# Out:
# marital
# w    725798
# m    705505
# s    286984
# d    220938
# u      2343
# a      2318
# Name: count, dtype: int64

# %% [markdown]
# 1778 values in the marital counts column have a value of "a" or "u", which were not described in the github we accessed the dataset from. However, 1778 is less than a percent of our data, so we will just drop the rows, alongside the 4 weird rows in the sex column

# %%
df_clean = df_clean[((df_clean["marital"] != "a") & (df_clean["marital"] != "u")) & (df_clean["sex"] != "u")]

# %% [markdown]
# Now that we've cleaned weird data, let's save our processed work

# %%
df_clean.to_csv("data/02-processed/birthdays_processed.csv", index=False)

print("Original shape:", df.shape)
print("Cleaned shape:", df_clean.shape)
# Out:
# Original shape: (1955588, 4)
# Cleaned shape: (1939219, 4)

# %% [markdown]
# ### Summary of Statistics

# %% [markdown]
# #### Age at Death

# %%
df_clean["age_floor"].describe()
# Out:
# count    1.939219e+06
# mean     7.535524e+01
# std      1.625929e+01
# min      1.000000e+00
# 25%      6.700000e+01
# 50%      7.900000e+01
# 75%      8.700000e+01
# max      1.140000e+02
# Name: age_floor, dtype: float64

# %% [markdown]
# Age_floor refers to age at death, with the mean age at death being 75.1 and the median being 79. A higher median indicates a slight left skew, meaning there are younger deaths pulling the mean downward.
#
# The interquartile range spans from 67 years (25th percentile) to 87 years (75th percentile), indicating that the middle 50% of individuals died between ages 67 and 87. This suggests the dataset is heavily concentrated among older adults, which aligns with expected mortality patterns.
#
# The minimum recorded age is 1 year, and the maximum is 114 years, both of which fall within plausible biological limits. There are no obvious extreme outliers (e.g., negative ages or values above 120 after cleaning), suggesting the age variable appears valid and well-behaved.
#
# Overall, the distribution of age at death appears realistic and consistent with known mortality patterns.

# %% [markdown]
# #### Manner of Death

# %%
df_clean["manner"].value_counts()
# Out:
# manner
# n    1833568
# a      77103
# s      19097
# h       6296
# c       1576
# p        973
# t        606
# Name: count, dtype: int64

# %% [markdown]
# Manner of death is largely made up of 'n' (natural causes). This means that any birthday effect will be primarily impacted by natural cause deaths.

# %% [markdown]
# #### Marital Status

# %%
df_clean["marital"].value_counts()
# Out:
# marital
# w    725797
# m    705502
# s    286982
# d    220938
# Name: count, dtype: int64

# %% [markdown]
# Marital Status is still made up mostly of married people, with single being close behind, with a much smaller amount of divorcees and widows.

# %% [markdown]
# ### Conclusions
#
# The summary statistics indicate that:
#
# - The dataset is large and robust (~1.96 million records).
#
# - Age at death is concentrated among older adults and appears biologically plausible.
#
# - Most deaths are due to natural causes, consistent with general mortality patterns.
#
# - There are no obvious extreme outliers or structural anomalies in these core variables after cleaning.

# %% [markdown]
# ### First Analysis - Visual Inspection
#
# Some more words and stuff.  Remember notebooks work best if you interleave the code that generates a result with properly annotate figures and text that puts these results into context.  Every project will be different here... but some examples of analyses are: inferential statistics where you calculate p-values (like a t-test or a Monte Carlo simulation), regression models, or a machine learning model
#
# **NOTE** The final report should not be overly long.  If this analysis step is huge and complicated  and you went down a lot of dead ends, then you should do something about that.  Some options...
#
# 1) remove any analysis you later decided was unecessary side quest before checking in for the final hand in
# 2) if the code to do an analysis is very long (in either lines or in time to compute) put it in a different file.  In that file make write out results of analysis into `results/` and reload the results here instead of recalculating it. And make a statement here like "To see the code responsible for analyses see `path/to/some-file-name.ipynb_or.py`."

# %% [markdown]
# #### Load fully wrangled data from data/02-processed
#
# We load the fully processed dataset from data/02-processed to that our EDA is reproducible without requiring re-running the data download and wrangling steps.

# %%
PROCESSED_PATH = "data/02-processed/birthdays_processed.csv"

assert os.path.exists(PROCESSED_PATH), f"Processed file not found at {PROCESSED_PATH}"

df = pd.read_csv(PROCESSED_PATH)

# %% [markdown]
# #### Separate Data from Homicide Deaths to Non-homicide Deaths
#
# Here, we filter analyses into different groups: homicide victims vs. other causes of death. We will check for patterns in homicide deaths, and compare them to the group with non-homicide deaths to see if there is a group-wise pattern. The dataset with non-homicide deaths serves as a control group for baseline comparison. We will do this by creating a one-hot encoded variable that is equal to 1 if a death was due to homicide, and 0 if it wasn't. We also group the "age_floor" variable into broader age categories. Using age groups instead of individual ages helps reduce noise in the data and allows us to more easily compare demographic patterns across age ranges. These age groups will help us investigate whether younger individuals appear more frequently among homicide victims.

# %%
df["onehot_homicide"] = (df["manner"] == "h").apply(lambda x: int(x))
bins = [0, 18, 25, 35, 50, 65, 120]
labels = ["0-18", "19-25", "26-35", "36-50", "51-65", "65+"]

df["age_group"] = pd.cut(
    df["age_floor"],
    bins = bins,
    labels = labels,
    right = False)

print("Updated Ages")
display(df.head())
# Out:
# Updated Ages
#    age_floor sex marital manner  onehot_homicide age_group
# 0          1   f       s      n                0      0-18
# 1          1   f       s      n                0      0-18
# 2          1   m       s      n                0      0-18
# 3          1   f       s      n                0      0-18
# 4          1   f       s      n                0      0-18

# %% [markdown]
# #### EDA Plot 1: Death rates over age

# %%
import seaborn as sns
import matplotlib.pyplot as plt

no_homicide = df[df["onehot_homicide"] == 0]
homicide = df[df["onehot_homicide"] == 1]

sns.histplot(no_homicide, x = "age_group", stat = "proportion")
plt.title("Proportion of Regular Deaths by Age Group")
plt.ylabel("Proportion")
plt.xlabel("Age Group")
plt.xticks(rotation=45)

plt.show()

sns.histplot(homicide, x = "age_group", stat = "proportion", color = "salmon")
plt.title("Proportion of Homicides by Age Group")
plt.ylabel("Proportion")
plt.xlabel("Age Group")
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# The age distribution for non-homicide deaths peak at 65+, which is also to be expected, as most non-homicidal deaths are related to old age and declining health issues that follow.
#
# In comparison, the distribution of homicide victims in our dataset peaks between ages 19-25. This supports the hypothesis that younger individuals may be more exposed to environments associated with violent crime.
#
# The age distribution of homicide victims is skewed toward younger age groups compared to non homicide deaths. While non-homicide deaths occur more frequently among older individuals, homicide deaths appear more concentrated among individuals in early adulthood. This suggests that age may play a role in distinguishing homicide deaths from other causes of death, rather than simply reflecting overall mortality patterns.

# %% [markdown]
# #### EDA Plot 2: Death rate over age controlled for sex
#
# Okay, let's control for gender and see what happens:

# %%
sns.histplot(no_homicide, x = "age_group", stat = "proportion", hue = "sex", element = "step")
plt.title("Proportion of Regular Deaths by Age Group")
plt.ylabel("Proportion")
plt.xlabel("Age Group")
plt.xticks(rotation=45)

plt.show()

sns.histplot(homicide, x = "age_group", stat = "proportion", hue = "sex", element = "step")
plt.title("Proportion of Homicides by Age Group")
plt.ylabel("Proportion")
plt.xlabel("Age Group")
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# Ok, now we are seeing some interesting things. Remember that d made up entries where the gender was not stated. After controlling for gender, it looks like the trends for regular death are the same across gender. However, when looking at homicide deaths, we some slightly differing trends. Declined to state gender had homicide death rates peak at the 19-25 age range, while males homicide death rates peaked from the 26-35 age range. Female homicide death rates peaked at the 36-50 age range, and the female homicide proportion was much lower than the previous two. This supports our hypothesis that young men are more likely to be homicide victims. It's also worth noting that the declined to state class seems to correlate pretty well with males, which goes against our earlier presented hypothesis that it would mostly be made up of females.

# %% [markdown]
# #### EDA Plot 3: Death rate over age controlled for Marital status

# %%
sns.histplot(no_homicide, x = "age_group", stat = "proportion", hue = "marital", element = "step")
plt.title("Proportion of Regular Deaths by Age Group")
plt.ylabel("Proportion")
plt.xlabel("Age Group")
plt.xticks(rotation=45)

plt.show()

sns.histplot(homicide, x = "age_group", stat = "proportion", hue = "marital", element = "step")
plt.title("Proportion of Homicides by Age Group")
plt.ylabel("Proportion")
plt.xlabel("Age Group")
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# For non-homicide deaths, the distribution is heavily concentrated in the 65+ age group, particularly among among individuals who are widowed and married. Younger age groups from 0-35 have very small proportions across all marital categories.
#
# In contrast, homicide deaths are concentrated in younger age groups, especially the ages 19-25 and 26-35. Within these groups, the majority of indiviudals are single, with relatively smaller proportions of married, divorced, or widowed individuals. As age increaes, the proportion of married and divorced indivudals rises slightly, but still remain lower compared to younger groups.
#
# This pattern suggests that the higher proportion of single individuals among homicide deaths is largely explained by the younger age distribution of those deaths. Since younger individuals are more likely to be unmarried, marital status differences appear to reflext age structure rather than an independent relationship.

# %% [markdown]
# #### EDA Plot 4: Boxplot Age at Death, controlling for gender and marital status

# %%
sns.boxplot(x = "marital", y = "age_floor", hue = "sex", data = homicide)
plt.xticks(
    rotation = 45,
    ticks = [0, 1, 2, 3],
    labels = ["Single", "Married", "Divorced", "Widowed"])
plt.title("Age Distribution by Marital Status in Homicide Deaths")
plt.ylabel("Age")
plt.xlabel("Marital Status")
plt.show()

sns.boxplot(x = "marital", y = "age_floor", data = no_homicide, hue = "sex")
plt.xticks(
    rotation = 45,
    ticks = [0, 1, 2, 3],
    labels = ["Single", "Married", "Divorced", "Widowed"])
plt.title("Age Distribution by Marital Status in Non-homicide Deaths")
plt.ylabel("Age")
plt.xlabel("Marital Status")
plt.show()

# %% [markdown]
# These boxplots compare how age varies across marital status categories for homicide and non-homicide deaths in the dataset.
#
# For homicide deaths, individuals who are single are the youngest, with median ages in the early-to-mid 20s. Married individuals are older, with medians around the late 30s to early 40s, while divorced individuals are slightly older still. Widowed individuals have the highest ages, typically in the 60+ range. This shows a clear progression where marital status aligns with increasing age.
#
# For non-homicide deaths, the entire age distribution is shifted upward. Across all marital categories, individuals are substantially older, with most medians ranging from the late 60s to 80s, especially for married and widowed individuals. The widowed group again shows the highest ages, consistent with expectations.
#
# Comparing the two plots, the key difference is that:
#
# - Homicide deaths are concentrated among younger individuals across all marital statuses
# - Non-homicide deaths occur primarily among older individuals, regardless of marital status
#
# Despite this shift, both plots show the same underlying structure:
#
# - Single: youngest
# - Married: middle-aged
# - Divorced: slightly older
# - Widowed: oldest
#
# This consistent pattern suggests that marital status is strongly tied to age, and the differences observed in marital status between homicide and non-homicide deaths are largely driven by differences in age distributions rather than independent effects.

# %% [markdown]
# #### Correlation Heatmap

# %%
df_corr = df.copy()

df_corr["is_homicide"] = (df_corr["manner"] == "h").astype(int)
df_corr = df_corr[["is_homicide", "age_floor", "marital", "sex"]].dropna()
df_corr["sex_male"] = (df_corr["sex"] == "m").astype(int)
marital_dummies = pd.get_dummies(df_corr["marital"], prefix = "marital")


corr_data = pd.concat([
    df_corr[["is_homicide", "age_floor", "sex_male"]],
    marital_dummies],
    axis = 1)

corr = corr_data.corr()

# Plot the correlational heatmap
plt.figure(figsize = (8, 6))
sns.heatmap(corr, annot = True, cmap = "coolwarm", center = 0, fmt = ".2f")
plt.title("Correlational Heatmap with Age & Marital Status Focus")
plt.xticks(rotation = 45, ha = "right")
plt.yticks(rotation = 0)
plt.show()

# %% [markdown]
# The correlation heatmap highlights relationships between age, marital status, and homicide within the dataset.
#
# Age shows a modest negative correlation with homicide (-0.15), indicating that homicide deaths tend to occur at younger ages. Marital status variables shows lower correlations, but marital status of single has a noticable correlation of 0.09 (Since this is a dummy variable and homicide is a onehot variable, this can be looked at as a 9% increased probabibility to be homicide victims if you are single). However, age is strongly correlated with marital status, with younger individuals more likely to be single and older individuals more likely to be widowed. This indicates that the observed differences in marital status between homicide and non-homicide deaths are largely driven by age rather than an independent relationship. These patterns describe associations within the dataset and do not imply causation or generalize beyond the observed sample.

# %% [markdown]
# #### Summary of Key Statistics

# %%
df_stats = df.copy()

df_stats["death_type"] = np.where(
    df_stats["manner"] == "h",
    "Homicide",
    "Non-Homicide"
)

display(df_stats.groupby("death_type")["age_floor"].describe())
display(df_stats.groupby(["death_type", "marital"])["age_floor"].describe())
# Out:
#                   count       mean        std  min   25%   50%   75%    max
# death_type
# Homicide         6296.0  32.757147  15.772276  1.0  21.0  29.0  41.0  100.0
# Non-Homicide  1932923.0  75.493993  16.077486  1.0  67.0  79.0  87.0  114.0
#                          count       mean        std   min   25%   50%    75%  \
# death_type   marital
# Homicide     d           520.0  48.594231  12.650891  22.0  39.0  47.0  56.00
#              m          1058.0  43.655009  14.674039  17.0  33.0  41.0  52.00
#              s          4546.0  27.099868  11.463230   1.0  20.0  24.0  32.00
#              w           172.0  67.366279  17.181849  28.0  56.0  71.0  80.25
# Non-Homicide d        220418.0  69.382641  13.905802   1.0  60.0  70.0  80.00
#              m        704444.0  72.813972  13.084877   1.0  65.0  75.0  83.00
#              s        282436.0  62.784206  22.368464   1.0  47.0  66.0  81.00
#              w        725625.0  84.899233   9.959767   1.0  80.0  86.0  91.00
#
# ...

# %% [markdown]
# The summary statistics show that deaths classified as homicide in this dataset occur at younger ages than non-homicide deaths, with lower mean and median values. Within both death types, age also varies systematically by marital status, with single individuals tending to be younger and widowed individuals older. This indicates that age is closely associated with marital status and helps explain differences observed between homicide and non-homicide deaths in the dataset.

# %% [markdown]
# #### Visual Inspection Conclusion
#
# The exploratory analysis identifies clear differences between homicide and non-homicide deaths within the dataset, with age emerging as the central factor. Homicide deaths occur at younger ages, while non-homicide deaths are concentrated among older individuals.
#
# Marital status also differs across death types, with homicide deaths more frequently associated with individuals classified as single, and non-homicide deaths more commonly associated with married, divorced, or widowed individuals. However, both visualizations and summary statistics show that marital status is strongly related to age, with younger individuals more likely to be single and older individuals more likely to be widowed or married.
#
# Taken together, these results suggest that the observed differences in marital status between homicide and non-homicide deaths are largely explained by differences in age distributions rather than an independent relationship. Correlation analysis further supports this interpretation, showing that age is more strongly associated with homicide than marital status.

# %% [markdown]
# ### EDA Part 2: Logistic Regression

# %% [markdown]
# Now that we have visually inspected the data, we are going to use statsmodels to create a regression to see a numeric relationship between age and homicde rate that controls for marital status and age. For this part, we are combining widowed and divorced into a single category, to avoid perfectly predicted variables that throw off the rest of our coefficients.

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

# normalized_age = (df['age_floor'] - df['age_floor'].mean()) / df['age_floor'].std()
subset = df[["sex", "onehot_homicide", "marital", "age_floor"]].copy()
# subset["age_floor"] = normalized_age
subset["marital"] = subset["marital"].apply(lambda x: "d" if x == "w" else x)
subset.to_csv("data/02-processed/birthdaysubset.csv", index=False)
regression = smf.logit("onehot_homicide ~ age_floor + C(sex, Treatment(reference='m')) + C(marital, Treatment(reference='m'))", data=subset)
result = regression.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.014886
#          Iterations 12
#                            Logit Regression Results
# ...
# Dep. Variable:        onehot_homicide   No. Observations:              1939219
# Model:                          Logit   Df Residuals:                  1939213
# Method:                           MLE   Df Model:                            5
# Date:                Thu, 19 Mar 2026   Pseudo R-squ.:                  0.3185
# Time:                        03:34:00   Log-Likelihood:                -28868.
# converged:                       True   LL-Null:                       -42363.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                                                 coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# ...

# %%
ratios = result.params.apply(np.exp)
ratios
# Out:
# Intercept                                    0.293474
# C(sex, Treatment(reference='m'))[T.d]        0.955440
# C(sex, Treatment(reference='m'))[T.f]        0.413319
# C(marital, Treatment(reference='m'))[T.d]    0.790246
# C(marital, Treatment(reference='m'))[T.s]    1.891014
# age_floor                                    0.923274
# dtype: float64

# %% [markdown]
# According to the logistic regression, almost all the parameters showed statistical significance. The only exception to this was that in comparison to male entries, "d" (declined to state) had a very low change in odds. This supports our earlier visual graphs which suggested that "declined to state" was closely aligned with and might be made up of mostly male entries. On the other hand, female entries showed about a 59% decrease in odds of being homicide victims, with a p-value of 0 (practically no chance this is a coincidence). In comparison to married people, unmarried people (divorced and widowed), showed a 21% decrease in odds of being homicide victims, while single people showed about an 89% INCREASE in odds for being homicide victims, both also having a P-value of 0. Finally, age showed about a 7.8% decrease in odds of being a homicide victim per year.
#
# That being said, the logistic regression gave a warning of quasi-separation, with a fraction of 0.10 of the observations being perfectly predicted. After looking into this, this is saying that a fraction of the observations are being assigned the exact perfect probability (If a homicide observation is assigned a 100% estimated homicide probability, it is a perfect prediction, and if a non-homicide observation is assigned an estimated 0% homicide probability, it is also a perfect prediction) The reason this is bad is because this can cause certain parameters to be prioritized over all others in situations that they shouldn't be, and be pushed to positive or negative infinities. This would throw off the coefficients for other parameters. After toying with the logistic regression hyperparameters, we managed to get the quasi separation to 0.10, and through inspection of the final output none of the parameters seem to be mapped to egregious final results. It's worth keeping in mind though, and could mean that our data has been overfit.

# %% [markdown]
# To more closely inspect the variables individually, we are going run individual regressions and see how much the Pseudo R^2 changes when accounting for different variables

# %% [markdown]
# Because our dataset is so large and we are running multiple logistic regressions, this takes quite a while to run, so we put the regressions in a separate notebook, Individual_Logistic_Regressions.ipynb. The individual tables are available for viewing there, but right now we are just looking at the R-squares.

# %%
rsquares = pd.read_csv("data/02-processed/rsquares.csv")
rsquares
# Out:
#                      Model  R-squared
# 0                Just age:   0.301174
# 1                Just sex:   0.014984
# 2     Just marital status:   0.127074
# 3             Age and sex:   0.312453
# 4  Age and marital status:   0.311891
# 5  Marital status and sex:   0.136119

# %% [markdown]
# Using this, we can see that while each of these variables had very strong P-values, the actual overall impact that some of them were making weren't that strong. Our R-squared from our earlier regression was about 31%. Individually, age by itself had an R-squared of 30%, which means that is almost just as strong of a predictor by itself, as it was when it was combined with the other variables. Marital status by itself had an R-squared of about 12% indicating that while it wasn't as significant of a variance explainer as age, it still makes a difference. Combined with age, it received an R-squared of about 31% nearly identical to the R-squared with all three variables. Sex on the other hand, had an R-squared of just over 1%. This tells us that while it had a statistically significant p-value and a strong meaningful effect, it doesn't explain most of the overall variation in our data.

# %% [markdown]
# # Final Conclusion
#
# While all the variables we investigated showed statistical significance with a P-value of 0, some were stronger than others.
#
# Age seemed to be the strongest predictor, showing an 8% decrease in homicide odds per year, and an R-squared showing that it explains about 30% of the variance.
#
# Marital status also showed to be a strong predictor, with unmarried people (divorced or widowed) showing a 21% decrease in likelihood to be homicide victims, and single people showing an 89% increase in likelihood. The R-squared showed that marital status accounts for about 12% of the variance in the data. When combined with age, the R-squared was almost the same as just the R-squared of age, suggesting that marital status and age are highly correlated predictors (which makes sense) and that using them together doesn't make much more of a difference than just using age.
#
# Sex showed that women were 59% less likely to be homicide victims than men, but it had a fairly low R-squared of just over 1%, suggesting that sex does not explain a lot of the variance in our data, and by itself would not be great predictor.

# %% [markdown]
# ## Ethics

# %% [markdown]
# #### A. Data Collection
# *A.1 Informed Consent*
#
# The dataset was collected by the Massachusetts Registry of Vital Records and Statistics for administrative purposes and later released publicly through a Freedom of Information Act request. Because the dataset is publicly available and contains no personally identifiable information (PII), informed consent from individuals was not required for this analysis.
#
# *A.2 Collection Bias*
#
# Several potential sources of bias may be present in the original data collection process. These include underreporting of incidents, differences in how manners of death are classified, and systemic or institutional factors that may influence whether deaths are recorded as homicides. Additionally, the dataset only reflects deaths occurring in Massachusetts and may not represent trends in other regions. These limitations are acknowledged, and conclusions from this analysis are restricted to the population and timeframe represented in the dataset.
#
# *A.3 Limiting PII Exposure*
#
# The dataset contains no personally identifiable information such as names, addresses, or identification numbers. Because the data is already anonymized and aggregated, the risk of identifying individuals is minimal.
#
# *A.4 Downstream Bias Mitigation*
#
# Some demographic variables such as age, sex, and marital status are included in the dataset. These variables were used cautiously to explore potential disparities and patterns in the data. Any findings involving demographic variables are presented descriptively and should not be interpreted as causal explanations for differences between groups.
#
# #### B. Data Storage
# *B.1 Data Security*
#
# The raw dataset is publicly available online. Our processed datasets, analysis scripts, and results will be stored in a project repository and made publicly available after the project is completed to ensure transparency and reproducibility. Because the dataset contains no PII, risks associated with public storage are minimal.
#
# *B.2 Right to Be Forgotten*
#
# Because the dataset does not contain personally identifiable information and is maintained by an external public source, individuals cannot request removal of specific records through this project. Requests regarding the original dataset would need to be directed to the agency responsible for maintaining the data.
#
# *B.3 Data Retention Plan*
#
# The processed datasets and analysis code will remain available as part of the public project repository to support reproducibility and transparency. The original raw dataset will continue to be hosted by the organization that released it.
#
# #### C. Analysis
# *C.1 Missing Perspectives*
#
# Homicide rates are influenced by complex social, economic, environmental, and institutional factors that are not fully captured in this dataset. The analysis acknowledges these limitations and avoids drawing conclusions that attribute causation to the patterns observed. Interpretations are framed carefully to avoid oversimplifying the factors contributing to violence.
#
# *C.2 Dataset Bias*
#
# The dataset may contain biases related to reporting practices, classification decisions, and incomplete records. Data cleaning steps such as removing records with missing information, excluding infant deaths under 1.5 years old, and removing February 29 entries were performed to enable consistent month-by-month comparisons. However, these decisions may introduce bias by excluding certain cases, and these limitations are documented in the project.
#
# *C.3 Honest Representation*
#
# All visualizations, summary statistics, and written interpretations are designed to accurately represent the underlying data. Visual choices such as axis scaling, aggregation methods, and labeling are selected to avoid misleading representations of trends or patterns.
#
# *C.4 Privacy in Analysis*
#
# Only anonymous and aggregated data are used in the analysis. Individual cases are not highlighted, and all reported results are presented in aggregated form to further reduce the risk of identifying individuals.
#
# *C.5 Auditability*
#
# All data processing, cleaning, and analysis steps are documented in the project repository. Code and documentation will be made publicly available so that other researchers can reproduce the analysis and verify the results.
#
# #### D. Modeling
# *D.1 Proxy Discrimination*
#
# No predictive or decision-making model is used in this project. The analysis is descriptive and exploratory rather than predictive.
#
# *D.2 Fairness Across Groups*
#
# Because the project does not involve predictive modeling, fairness testing for model outputs is not applicable.
#
# *D.3 Metric Selection*
#
# The analysis relies on descriptive statistics and visualizations rather than optimization of model metrics.
#
# D.4 Explainability
#
# Since no predictive model is used, model explainability is not required.
#
# D.5 Communicating Limitations
#
# The project clearly communicates that the results identify correlations and descriptive patterns rather than causal relationships. Findings are limited to the Massachusetts dataset and the specific timeframe analyzed.
#
# #### E. Deployment
# E.1 Monitoring and Evaluation
#
# This project is intended for research and educational purposes. While no system will be deployed, the publicly available code and analysis could be extended in the future to incorporate additional datasets, locations, or time periods.
#
# E.2 Redress
#
# Because the analysis does not produce decisions that affect individuals, there is minimal risk of direct harm. However, interpretations are presented cautiously to reduce the risk of misuse or misrepresentation.
#
# E.3 Rollback
#
# No production system or automated model is deployed as part of this project.
#
# E.4 Unintended Use
#
# Because the analysis will be publicly available, there is a possibility that results could be misinterpreted or used to support misleading narratives. To mitigate this risk, the project clearly communicates the dataset’s limitations and emphasizes that seasonal patterns alone cannot explain the underlying causes of homicide or violence.

# %% [markdown]
# ## Discusison and Conclusion
#
# Wrap it all up here.  Somewhere between 3 and 10 paragraphs roughly.
# 1. Summarize the important results you made
# 2. This is a good time to refer back to your Background section and review how this work extended the previous stuff.
# 3. Try to bring all the different results together into a bigger picture... what have we learned?
# 4. Often what we learned is confusing.  Discuss if there are contradictory results how that might have happened
# 5. Discuss the limitations of your work. e.g, is the dataset a biased sample? would more data make you more confident? would longitudinal instead of cross-sectional data helpful? is there evidence that the phenomena you're investigating may change over time? etc
# 6. If you would like, you can also say what the next steps in this investigation might be if the work was to continue outside this class
